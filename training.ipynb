# %%
# Python Identifier Naming Rules:
# 1. Identifiers can be a combination of letters (a-z, A-Z), digits (0-9), and underscores (_).
# 2. Identifiers cannot start with a digit.
# 3. Identifiers are case-sensitive (e.g., 'myVar' is different from 'myvar').
# 4. Reserved keywords (e.g., 'if', 'else', 'for', 'while', 'class', 'def') cannot be used as identifiers.
# 5. Identifiers can be of any length.
# 6. Avoid using special characters like !, @, #, $, %, etc., in identifiers.

# %%
print(6+10,10-6,10*6,10/6,10%6)
# Out:
# 16 4 60 1.6666666666666667 4

# %%
a=10
b=20
c=10
print(a==c and a<b)
print(a==c or a>b)
print(not a<b)
# Out:
# True False False

# %%
a=10
res=50
print(res)
res+=a
print(res)
res-=a
print(res)
res*=a
print(res)
res/=a
print(res)
# Out:
# 50
# 60
# 50
# 500
# 50.0

# %%
a=20
b=10.0
print(float(a)+b)
# Out:
# 30.0

# %%
a=input('enter the number')
b=int(input('enter the number'))
print(type (a))
print(type(b))
# Out:
# enter the number45
# enter the number788
# <class 'str'>

# %%
r=int(input('enter the radius:'))
h=int(input('enter the height:'))
print('area of cylinder is ',2*3.14*r*h)
# Out:
# enter the radius:2
# enter the height:6
# area of cylinder is  75.36

# %%
n1=float(input('enter the first number:'))
n2=float(input('enter the second number:'))
print("average :",(n1+n2)/2)
# Out:
# enter the first number:15
# enter the second number:45
# average : 30.0

# %%
a=int(input("enter n1:"))
b=int(input('enter n2:'))
if a>=b:
  print(True)
else:
  print(False)
# Out:
# enter n1:60
# enter n2:20
# True

# %%
a='Tce engineering college'
a.split(' ')
# Out:
# ['Tce', 'engineering', 'college']

# %%
a='amazing'
a[1:6:2]
# Out:
# 'mzn'

# %%
name=input("enter the  first name:")
len(name)
# Out:
# enter the  first name:rakshak
# 7

# %%
s=input("enter the string:")
print(s.find('$'))
# Out:
# enter the string:hsgd $
# 5

# %%
s=input("enter the string:")
print(s.endswith('ng'))
# Out:
# enter the string:rocking challenging
# True

# %%
s=input("enter the string:")
print(s.count('the'))
# Out:
# enter the string:the the the
# 3

# %%
s='skdhdjfjgfh'
s.capitalize()
# Out:
# 'Skdhdjfjgfh'

# %%
s=input("enter the string:")
print(s.find('python'))
print(s.count('python'))
# Out:
# enter the string:jsdhf python jf python ghdfgpython hdgfh python
# 6
# 4

# %%
mark=int(input('enter the number:'))
if mark>=90:
  print('A')
elif mark>=80:
  print('B')
elif mark>=70:
  print('C')
elif mark>=60:
  print('D')
else:
  print('Fail')
# Out:
# enter the number:25
# Fail

# %%
n=int(input('enter the number:'))
l=['even','odd']
print(l[n%2])
# Out:
# enter the number:86
# even

# %%
li=[]
for i in range(3):
  n=int(input('enter the number:'))
  li.append(n)
print(max(li))#[n1,n2,n3]
# Out:
# enter the number:121
# enter the number:58
# enter the number:1
# 121

# %%
n=int(input('enter the number:'))
if n%7==0:
  print('multiple of 7')
else:
  print('not a multiplle of 7')
# Out:
# enter the number:11
# not a multiplle of 7

# %%
#leap year
n=int(input('enter the number:'))
if n%4==0:
  print('leap year')
else:
  print('not a leap year')
# Out:
# enter the number:2001
# not a leap year

# %%
n=int(input('enter the number:'))

if 0>n:
  print('negative')
elif n==0:
  print('zero')
else:
    print('positive')
# Out:
# enter the number:0
# zero

# %%
l=[5,9,2,1,7]
l.pop()
l
# Out:
# [5, 9, 2, 1]

# %%
a=(1,2,3,4,5,5)
print(a)
'''b=(1,2,3,4,5)
print(b)'''
print(a.index(4))
print(a.count(5))
# Out:
# (1, 2, 3, 4, 5, 5)
# 3
# 2

# %%
l=[]
for i in range(3):
  m=input('enter the movie1:')
  l.append(m)
print(l)
# Out:
# enter the movie1:a
# enter the movie1:b
# enter the movie1:c
# ['a', 'b', 'c']

# %%
l=[1,2,3,2,1]
a=l.copy()
a.reverse()
if l==a:
  print('palindrome')
else:
  print('not a palindrome')
# Out:
# palindrome

# %%
t=['c','a','d','a','a','b','b','a']
print(t.count('a'))
l=list(t)
t.sort(reverse=False)
t
# Out:
# 4
# ['a', 'a', 'a', 'a', 'b', 'b', 'c', 'd']

# %% [markdown]
# **29-02-26**

# %%
l=[1,2,3,48,79,15]
su=0
for el in l:
  su+=el
print('sum:',sum)
# Out:
# sum: 47

# %%
max(l)
# Out:
# 79

# %%
min(l)
# Out:
# 1

# %%
ll=[11,2,5,8,11,2,8]
ss=set(ll)
s=list(ss)
print(s)
# Out:
# [8, 2, 11, 5]

# %%
tup=(11,2,5,8,11,2,8)
sum=0
for el in tup:
  sum+=el
print(  'sum',sum)
# Out:
# sum 47

# %%
len(ll)
# Out:
# 7

# %%
'''
dictionary:builtin,key-value pair,un-ordered,mutable,no duplicate keys
{}
'''

# %%
d={'table':['a piece of furniture','lists of facts and figures'],
   'cat':'a small element ',
   }
print(d)
# Out:
# {'table': ['a piece of furniture', 'lists of facts and figures'], 'cat': 'a small element '}

# %%
s={'python','java','c++','python','javascript','java','python','java','c++','c'}
print('number of class room required:',len(s))
# Out:
# number of class room required: 5

# %%
d={}
for i in range(3):
  subject=input(f'subject {i}:')
  marks=int(input(f'marks of {subject}:'))
  d.update({subject:marks})
print('displaying dictionary:',d)
# Out:
# subject0:maths
# marks of maths:95
# subject1:science
# marks of science:90
# subject2:social
# marks of social:100
# displaying dictionary: {'maths': '95', 'science': '90', 'social': '100'}

# %%
s={(int,9),(float,9.0)}
print(s)
# Out:
# {9}

# %%
l=[1,2,3,2,1]
n=[]
for el in l:
  if el in n:
    continue
  else:
    n.append(el)
print(n)
# Out:
# [1, 2, 3]

# %% [markdown]
# **2-03-2026**
